# %%
#############THIS CODE IS WRITTEN FOR PAPER IRMRIS###########
############# FOR ABLATION STUDY EVALUATE##################
############Dated: 20-02-2022######################

# %%
##################HERE WE USED WITH SKIP CONNECTIONS#############

# %%
from numpy import clip
from keras.layers.advanced_activations import PReLU
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.layers import Conv2D, Input, Lambda
from tensorflow.keras.models import Model
from tensorflow.nn import depth_to_space
from tensorflow import clip_by_value
import HelpFunc as hf
from tensorflow.keras.layers import Input, Conv2D, Activation, SeparableConv2D
from tensorflow.keras.layers import PReLU
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, ReLU, Concatenate, add, Activation, Dropout

# %%
def ResNet_block():
    _input = Input(shape=(None, None, 1))

    C1 = Conv2D(1, (3, 3), strides=(1, 1), padding='same')(_input)
    R1 = ReLU()(C1)
    R1 = ReLU()(C1)
  
    C2 = Conv2D(1, (1,1), strides=(1, 1), padding='same')(R1)

    sum1 = add(inputs=[_input ,C1,C2])

    
    C3 = Conv2D(1,(3,3), strides=(1, 1), padding='same')(sum1)
    R2 = ReLU()(C3)

    C4 = Conv2D(1, (1,1), strides=(1, 1), padding='same')(R2)

    sum2 = add(inputs=[_input, sum1, C4])
 
    
    model = Model(inputs=_input, outputs=sum2)

    return model
model = ResNet_block()

# %%
def Multi_Path_Inception_Block():
    _input = Input(shape=(None, None, 1))
    C1 = Conv2D(1, (1,1),strides=(1,1),padding='same')(_input)

    
    #First barnch Second Block
    C2 = Conv2D(22, (3,3),strides=(1,1),padding='same')(C1)
    R2 = ReLU()(C2)

    C3 = Conv2D(22, (3,3),strides=(1,1),padding='same')(R2)
    R3 = ReLU()(C3)

    
    #Second Branch
    C4 = Conv2D(22, (5,5),strides=(1,1),padding='same')(C1)
    R4 = ReLU()(C4)

    C5 = Conv2D(22, (5,5),strides=(1,1),padding='same')(R4)
    R5 = ReLU()(C5)

    #Third Branch
    C6 = Conv2D(22, (7,7),strides=(1,1),padding='same')(C1)
    R6 = ReLU()(C6)

    C7 = Conv2D(22, (7,7),strides=(1,1),padding='same')(R6)
    R7 = ReLU()(C7)

    
    sum3 = add(inputs=[C1, R3, R5, R7])
    
  
    C8 = Conv2D(1, (1,1),strides=(1,1),padding='same')(sum3)
    
    model = Model(inputs=_input, outputs=C8)

    return model
model = Multi_Path_Inception_Block()

# %%
def IRMRIS():
    scale = 4
    X_in = Input(shape=(None, None, 1))

    X1 = Conv2D(64, (5,5), padding='same', activation='relu')(X_in)
    X2 = Conv2D(1, (3,3), padding='same', activation='relu')(X1)
    X3 = ResNet_block()(X2)
    sum1 = add(inputs=[X2,X3])
    X4 = ResNet_block()(sum1)
    sum2 = add(inputs=[sum1, X4])
    X5 = ResNet_block()(sum2)
    sum3 = add(inputs=[sum2,X5])
    X6 = ResNet_block()(sum3)
    sum4 = add(inputs=[sum3,X6])
    X7 = Multi_Path_Inception_Block()(sum4)
    sum5 = add(inputs=[sum4,X7])
    X8 = Multi_Path_Inception_Block()(sum5)
    sum6 = add(inputs=[sum5,X8])
    X9 = Multi_Path_Inception_Block()(sum6)
    sum7 = add(inputs=[sum6,X9])
    X10 = Multi_Path_Inception_Block()(sum7)
    sum8 = add(inputs=[sum7,X10])
    XA = Conv2D(32, (3,3), padding='same', activation='relu')(sum8)

    Y = Conv2DTranspose(filters=3, kernel_size = (9,9), strides = (scale,scale), padding="same",activation=None)(XA)

    X_out = depth_to_space(Y, scale)
    model = Model(inputs=X_in, outputs=X_out)


    model.compile(optimizer=Adam(learning_rate=1e-3),loss=MeanSquaredError(),metrics=[hf.PSNR])

    return model

# %%
from tabnanny import verbose
import tensorflow as tf
from Model import IRMRIS
import pandas as pd
import HelpFunc as hf
import numpy as np
import argparse
import os

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--epoch', type=int, default=100, help='-')
parser.add_argument('--batch_size', type=int, default=128, help='-')

FLAGS, unparsed = parser.parse_known_args()

X_tr = np.load("dataset/data_train.npy")
Y_tr = np.load("dataset/labels_train.npy")

X_val = np.load("dataset/data_validation.npy")
Y_val = np.load("dataset/labels_validation.npy")

X_te = np.load("dataset/data_test.npy")
Y_te = np.load("dataset/labels_test.npy")

model = IRMRIS()

ckpt_path = "checkpoint/model-ckpt"
ckpt_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=ckpt_path,
    save_weights_only=True,
    verbose=1
)

if os.path.exists(f"{ckpt_path}.index"):
    print(f"\n\nLoad Model from \"{ckpt_path}\"")
    model.load_weights(ckpt_path)
else:
    print(f"\n\n\"{ckpt_path}\" DO NOT EXIST")


if os.path.exists("checkpoint/cur_epoch.npy"):
    cur_epoch = np.load("checkpoint/cur_epoch.npy")
else:
    cur_epoch = np.int32(0)
print(f"\n\nCurrent epoch is {cur_epoch}\n")


print("\n\n==================================================",
      " Train ",
      "==================================================\n")

history = model.fit(
    x=X_tr, y=Y_tr,
    batch_size=FLAGS.batch_size,
    epochs=FLAGS.epoch,
    validation_data=(X_val, Y_val),
    callbacks=[ckpt_callback],
    verbose=1
)

print("\n\n==================================================",
      " Evaluate ",
      "==================================================\n")

model.evaluate(X_te, Y_te)

df = pd.DataFrame(history.history)
df = hf.AppendHistory(df)
df.to_csv("history.csv", index=False)

cur_epoch = cur_epoch + FLAGS.epoch
print(f"\nTotal trained epochs is {cur_epoch}\n")

np.save("checkpoint/cur_epoch.npy", cur_epoch)
# Out:
# "checkpoint/model-ckpt" DO NOT EXIST
#
#
# Current epoch is 0
#
#
#
# ==================================================  Train  ==================================================
#
# Epoch 1/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0246 - PSNR: 17.4764
# Epoch 00001: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 7s 10ms/step - loss: 0.0246 - PSNR: 17.4764 - val_loss: 0.0093 - val_PSNR: 20.3218
# Epoch 2/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0071 - PSNR: 21.5390
# Epoch 00002: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 4s 9ms/step - loss: 0.0071 - PSNR: 21.5481 - val_loss: 0.0064 - val_PSNR: 21.9391
# Epoch 3/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0049 - PSNR: 23.1068
# Epoch 00003: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 4s 9ms/step - loss: 0.0049 - PSNR: 23.1133 - val_loss: 0.0045 - val_PSNR: 23.5331
# Epoch 4/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0038 - PSNR: 24.1865
# Epoch 00004: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0038 - PSNR: 24.1910 - val_loss: 0.0037 - val_PSNR: 24.3666
# Epoch 5/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0033 - PSNR: 24.8930
# Epoch 00005: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0033 - PSNR: 24.8928 - val_loss: 0.0032 - val_PSNR: 24.9385
# Epoch 6/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0029 - PSNR: 25.4803
# Epoch 00006: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0029 - PSNR: 25.4800 - val_loss: 0.0028 - val_PSNR: 25.4900
# Epoch 7/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0025 - PSNR: 25.9799
# Epoch 00007: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0025 - PSNR: 25.9799 - val_loss: 0.0027 - val_PSNR: 25.7341
# Epoch 8/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0024 - PSNR: 26.2901
# Epoch 00008: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0024 - PSNR: 26.2886 - val_loss: 0.0025 - val_PSNR: 26.0997
# Epoch 9/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0023 - PSNR: 26.4810
# Epoch 00009: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0023 - PSNR: 26.4859 - val_loss: 0.0024 - val_PSNR: 26.2549
# Epoch 10/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0022 - PSNR: 26.6267
# Epoch 00010: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0022 - PSNR: 26.6287 - val_loss: 0.0023 - val_PSNR: 26.3624
# Epoch 11/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0021 - PSNR: 26.7228
# Epoch 00011: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0021 - PSNR: 26.7187 - val_loss: 0.0023 - val_PSNR: 26.4339
# Epoch 12/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0021 - PSNR: 26.7994
# Epoch 00012: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0021 - PSNR: 26.7994 - val_loss: 0.0023 - val_PSNR: 26.4851
# Epoch 13/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0021 - PSNR: 26.8464
# Epoch 00013: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0021 - PSNR: 26.8463 - val_loss: 0.0022 - val_PSNR: 26.5339
# Epoch 14/100
# 386/394 [============================>.] - ETA: 0s - loss: 0.0021 - PSNR: 26.8854
# Epoch 00014: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0021 - PSNR: 26.8783 - val_loss: 0.0023 - val_PSNR: 26.4956
# Epoch 15/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0020 - PSNR: 26.9626
# Epoch 00015: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0020 - PSNR: 26.9638 - val_loss: 0.0022 - val_PSNR: 26.5272
# Epoch 16/100
# 392/394 [============================>.] - ETA: 0s - loss: 0.0020 - PSNR: 26.9737
# Epoch 00016: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0020 - PSNR: 26.9769 - val_loss: 0.0022 - val_PSNR: 26.6688
# Epoch 17/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0020 - PSNR: 27.0504
# Epoch 00017: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0020 - PSNR: 27.0476 - val_loss: 0.0022 - val_PSNR: 26.6215
# Epoch 18/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0020 - PSNR: 27.0864
# Epoch 00018: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0020 - PSNR: 27.0834 - val_loss: 0.0022 - val_PSNR: 26.5224
# Epoch 19/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.1854
# Epoch 00019: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.1824 - val_loss: 0.0021 - val_PSNR: 26.8904
# Epoch 20/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.2780
# Epoch 00020: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.2734 - val_loss: 0.0020 - val_PSNR: 26.9115
# Epoch 21/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.2898
# Epoch 00021: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.2908 - val_loss: 0.0020 - val_PSNR: 26.9352
# Epoch 22/100
# 392/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.2994
# Epoch 00022: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.2963 - val_loss: 0.0020 - val_PSNR: 26.9447
# Epoch 23/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3180
# Epoch 00023: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.3179 - val_loss: 0.0020 - val_PSNR: 26.9517
# Epoch 24/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0019 - PSNR: 27.3275
# Epoch 00024: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.3275 - val_loss: 0.0020 - val_PSNR: 26.9531
# Epoch 25/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3221
# Epoch 00025: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.3243 - val_loss: 0.0020 - val_PSNR: 26.9574
# Epoch 26/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3275
# Epoch 00026: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.3302 - val_loss: 0.0020 - val_PSNR: 26.9588
# Epoch 27/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3299
# Epoch 00027: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0019 - PSNR: 27.3313 - val_loss: 0.0020 - val_PSNR: 26.9688
# Epoch 28/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3297
# Epoch 00028: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.3287 - val_loss: 0.0020 - val_PSNR: 26.9651
# Epoch 29/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3387
# Epoch 00029: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.3407 - val_loss: 0.0020 - val_PSNR: 26.9698
# Epoch 30/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3391
# Epoch 00030: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.3399 - val_loss: 0.0020 - val_PSNR: 26.9726
# Epoch 31/100
# 386/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3539
# Epoch 00031: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.3540 - val_loss: 0.0020 - val_PSNR: 26.9678
# Epoch 32/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3441
# Epoch 00032: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.3463 - val_loss: 0.0020 - val_PSNR: 26.9734
# Epoch 33/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3457
# Epoch 00033: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3379 - val_loss: 0.0025 - val_PSNR: 26.0301
# Epoch 34/100
# 386/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3550
# Epoch 00034: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3464 - val_loss: 0.0020 - val_PSNR: 26.9782
# Epoch 35/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3561
# Epoch 00035: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3577 - val_loss: 0.0020 - val_PSNR: 26.9709
# Epoch 36/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3565
# Epoch 00036: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3545 - val_loss: 0.0020 - val_PSNR: 26.9797
# Epoch 37/100
# 392/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3457
# Epoch 00037: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3426 - val_loss: 0.0020 - val_PSNR: 26.9802
# Epoch 38/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3614
# Epoch 00038: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3614 - val_loss: 0.0020 - val_PSNR: 26.9825
# Epoch 39/100
# 386/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3540
# Epoch 00039: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3557 - val_loss: 0.0020 - val_PSNR: 26.9826
# Epoch 40/100
# 392/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3533
# Epoch 00040: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3537 - val_loss: 0.0020 - val_PSNR: 26.9807
# Epoch 41/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3499
# Epoch 00041: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3499 - val_loss: 0.0020 - val_PSNR: 26.9809
# Epoch 42/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3735
# Epoch 00042: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3751 - val_loss: 0.0020 - val_PSNR: 26.9852
# Epoch 43/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3573
# Epoch 00043: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0019 - PSNR: 27.3603 - val_loss: 0.0020 - val_PSNR: 26.9853
# Epoch 44/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3618
# Epoch 00044: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0019 - PSNR: 27.3593 - val_loss: 0.0020 - val_PSNR: 26.9818
# Epoch 45/100
# 386/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3643
# Epoch 00045: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3585 - val_loss: 0.0020 - val_PSNR: 26.9861
# Epoch 46/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3699
# Epoch 00046: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3699 - val_loss: 0.0020 - val_PSNR: 26.9846
# Epoch 47/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3548
# Epoch 00047: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3558 - val_loss: 0.0020 - val_PSNR: 26.9829
# Epoch 48/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0019 - PSNR: 27.3661
# Epoch 00048: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3661 - val_loss: 0.0020 - val_PSNR: 26.9867
# Epoch 49/100
# 385/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3676
# Epoch 00049: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3749 - val_loss: 0.0020 - val_PSNR: 26.9840
# Epoch 50/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3658
# Epoch 00050: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3651 - val_loss: 0.0020 - val_PSNR: 26.9866
# Epoch 51/100
# 386/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3696
# Epoch 00051: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3662 - val_loss: 0.0020 - val_PSNR: 26.9825
# Epoch 52/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0019 - PSNR: 27.3573
# Epoch 00052: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3573 - val_loss: 0.0020 - val_PSNR: 26.9581
# Epoch 53/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3758
# Epoch 00053: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3738 - val_loss: 0.0020 - val_PSNR: 26.9834
# Epoch 54/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3738
# Epoch 00054: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3694 - val_loss: 0.0020 - val_PSNR: 26.9576
# Epoch 55/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3703
# Epoch 00055: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3700 - val_loss: 0.0020 - val_PSNR: 26.9575
# Epoch 56/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3711
# Epoch 00056: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3698 - val_loss: 0.0020 - val_PSNR: 26.9893
# Epoch 57/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3717
# Epoch 00057: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3710 - val_loss: 0.0020 - val_PSNR: 26.9887
# Epoch 58/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3710
# Epoch 00058: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3710 - val_loss: 0.0020 - val_PSNR: 26.9839
# Epoch 59/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3778
# Epoch 00059: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3795 - val_loss: 0.0020 - val_PSNR: 26.9889
# Epoch 60/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3769
# Epoch 00060: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3722 - val_loss: 0.0021 - val_PSNR: 26.8272
# Epoch 61/100
# 385/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3781
# Epoch 00061: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3780 - val_loss: 0.0020 - val_PSNR: 26.9898
# Epoch 62/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3695
# Epoch 00062: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3706 - val_loss: 0.0021 - val_PSNR: 26.8855
# Epoch 63/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3789
# Epoch 00063: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3789 - val_loss: 0.0020 - val_PSNR: 26.9895
# Epoch 64/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3730
# Epoch 00064: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3757 - val_loss: 0.0020 - val_PSNR: 26.9868
# Epoch 65/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3646
# Epoch 00065: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3702 - val_loss: 0.0020 - val_PSNR: 26.9901
# Epoch 66/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3808
# Epoch 00066: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3818 - val_loss: 0.0020 - val_PSNR: 26.9883
# Epoch 67/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3771
# Epoch 00067: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3731 - val_loss: 0.0020 - val_PSNR: 26.9901
# Epoch 68/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3772
# Epoch 00068: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3772 - val_loss: 0.0020 - val_PSNR: 26.9883
# Epoch 69/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3729
# Epoch 00069: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3701 - val_loss: 0.0020 - val_PSNR: 26.9930
# Epoch 70/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3788
# Epoch 00070: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3784 - val_loss: 0.0020 - val_PSNR: 26.9522
# Epoch 71/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3794
# Epoch 00071: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3750 - val_loss: 0.0020 - val_PSNR: 26.9360
# Epoch 72/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3805
# Epoch 00072: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3805 - val_loss: 0.0020 - val_PSNR: 26.9909
# Epoch 73/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3762
# Epoch 00073: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3761 - val_loss: 0.0020 - val_PSNR: 26.9921
# Epoch 74/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3716
# Epoch 00074: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3704 - val_loss: 0.0020 - val_PSNR: 26.9918
# Epoch 75/100
# 385/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3660
# Epoch 00075: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3722 - val_loss: 0.0020 - val_PSNR: 26.9809
# Epoch 76/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3811
# Epoch 00076: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3811 - val_loss: 0.0020 - val_PSNR: 26.9929
# Epoch 77/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3795
# Epoch 00077: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3787 - val_loss: 0.0020 - val_PSNR: 26.9759
# Epoch 78/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3800
# Epoch 00078: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3810 - val_loss: 0.0020 - val_PSNR: 26.9925
# Epoch 79/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3788
# Epoch 00079: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 9ms/step - loss: 0.0018 - PSNR: 27.3774 - val_loss: 0.0020 - val_PSNR: 26.9928
# Epoch 80/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3746
# Epoch 00080: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3747 - val_loss: 0.0020 - val_PSNR: 26.9885
# Epoch 81/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3796
# Epoch 00081: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 9ms/step - loss: 0.0018 - PSNR: 27.3831 - val_loss: 0.0020 - val_PSNR: 26.9934
# Epoch 82/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3715
# Epoch 00082: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 9ms/step - loss: 0.0018 - PSNR: 27.3745 - val_loss: 0.0020 - val_PSNR: 26.9686
# Epoch 83/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3820
# Epoch 00083: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3813 - val_loss: 0.0020 - val_PSNR: 26.9739
# Epoch 84/100
# 392/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3791
# Epoch 00084: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3815 - val_loss: 0.0020 - val_PSNR: 26.9885
# Epoch 85/100
# 392/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3799
# Epoch 00085: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3782 - val_loss: 0.0020 - val_PSNR: 26.9937
# Epoch 86/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3765
# Epoch 00086: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3767 - val_loss: 0.0020 - val_PSNR: 26.9843
# Epoch 87/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3773
# Epoch 00087: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3795 - val_loss: 0.0020 - val_PSNR: 26.9953
# Epoch 88/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3796
# Epoch 00088: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3806 - val_loss: 0.0020 - val_PSNR: 26.9946
# Epoch 89/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3790
# Epoch 00089: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3823 - val_loss: 0.0020 - val_PSNR: 26.9816
# Epoch 90/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3776
# Epoch 00090: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3813 - val_loss: 0.0020 - val_PSNR: 26.9896
# Epoch 91/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3745
# Epoch 00091: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3781 - val_loss: 0.0020 - val_PSNR: 26.9939
# Epoch 92/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3792
# Epoch 00092: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3764 - val_loss: 0.0020 - val_PSNR: 26.9843
# Epoch 93/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3779
# Epoch 00093: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3803 - val_loss: 0.0020 - val_PSNR: 26.9761
# Epoch 94/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3795
# Epoch 00094: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3795 - val_loss: 0.0020 - val_PSNR: 26.9933
# Epoch 95/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3810
# Epoch 00095: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3829 - val_loss: 0.0020 - val_PSNR: 26.9956
# Epoch 96/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3815
# Epoch 00096: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3815 - val_loss: 0.0020 - val_PSNR: 26.9929
# Epoch 97/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3818
# Epoch 00097: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3818 - val_loss: 0.0020 - val_PSNR: 26.9893
# Epoch 98/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3799
# Epoch 00098: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3799 - val_loss: 0.0020 - val_PSNR: 26.9911
# Epoch 99/100
# 392/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3843
# Epoch 00099: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3826 - val_loss: 0.0020 - val_PSNR: 26.9960
# Epoch 100/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3831
# Epoch 00100: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3831 - val_loss: 0.0020 - val_PSNR: 26.9975
#
#
# ==================================================  Evaluate  ==================================================
#
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0021 - PSNR: 26.9695
#
#
# history file does not exist
#
#
# Total trained epochs is 100
