# %%
#############THIS CODE IS WRITTEN FOR PAPER IRMRIS###########
############# FOR ABLATION STUDY EVALUATE##################
############Dated: 20-02-2022######################

# %%
##################HERE WE USED WITH SKIP CONNECTIONS#############

# %%
from numpy import clip
from keras.layers.advanced_activations import PReLU
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.layers import Conv2D, Input, Lambda
from tensorflow.keras.models import Model
from tensorflow.nn import depth_to_space
from tensorflow import clip_by_value
import HelpFunc as hf
from tensorflow.keras.layers import Input, Conv2D, Activation, SeparableConv2D
from tensorflow.keras.layers import PReLU
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, ReLU, Concatenate, add, Activation, Dropout

# %%
def ResNet_block():
    _input = Input(shape=(None, None, 1))

    C1 = Conv2D(1, (3, 3), strides=(1, 1), padding='same')(_input)
    R1 = ReLU()(C1)
    R1 = ReLU()(C1)
  
    C2 = Conv2D(1, (1,1), strides=(1, 1), padding='same')(R1)

    sum1 = add(inputs=[_input ,C1,C2])

    
    C3 = Conv2D(1,(3,3), strides=(1, 1), padding='same')(sum1)
    R2 = ReLU()(C3)

    C4 = Conv2D(1, (1,1), strides=(1, 1), padding='same')(R2)

    sum2 = add(inputs=[_input, sum1, C4])
 
    
    model = Model(inputs=_input, outputs=sum2)

    return model
model = ResNet_block()

# %%
def Multi_Path_Inception_Block():
    _input = Input(shape=(None, None, 1))
    C1 = Conv2D(1, (1,1),strides=(1,1),padding='same')(_input)

    
    #First barnch Second Block
    C2 = Conv2D(22, (3,3),strides=(1,1),padding='same')(C1)
    R2 = ReLU()(C2)

    C3 = Conv2D(22, (3,3),strides=(1,1),padding='same')(R2)
    R3 = ReLU()(C3)

    
    #Second Branch
    C4 = Conv2D(22, (5,5),strides=(1,1),padding='same')(C1)
    R4 = ReLU()(C4)

    C5 = Conv2D(22, (5,5),strides=(1,1),padding='same')(R4)
    R5 = ReLU()(C5)

    #Third Branch
    C6 = Conv2D(22, (7,7),strides=(1,1),padding='same')(C1)
    R6 = ReLU()(C6)

    C7 = Conv2D(22, (7,7),strides=(1,1),padding='same')(R6)
    R7 = ReLU()(C7)

    
    sum3 = add(inputs=[C1, R3, R5, R7])
    
  
    C8 = Conv2D(1, (1,1),strides=(1,1),padding='same')(sum3)
    
    model = Model(inputs=_input, outputs=C8)

    return model
model = Multi_Path_Inception_Block()

# %%
def IRMRIS():
    scale = 4
    X_in = Input(shape=(None, None, 1))

    X1 = Conv2D(64, (5,5), padding='same', activation='relu')(X_in)
    X2 = Conv2D(1, (3,3), padding='same', activation='relu')(X1)
    X3 = ResNet_block()(X2)
    sum1 = add(inputs=[X2,X3])
    X4 = ResNet_block()(sum1)
    sum2 = add(inputs=[sum1, X4])
    X5 = ResNet_block()(sum2)
    sum3 = add(inputs=[sum2,X5])
    X6 = ResNet_block()(sum3)
    sum4 = add(inputs=[sum3,X6])
    X7 = Multi_Path_Inception_Block()(sum4)
    sum5 = add(inputs=[sum4,X7])
    X8 = Multi_Path_Inception_Block()(sum5)
    sum6 = add(inputs=[sum5,X8])
    X9 = Multi_Path_Inception_Block()(sum6)
    sum7 = add(inputs=[sum6,X9])
    X10 = Multi_Path_Inception_Block()(sum7)
    sum8 = add(inputs=[sum7,X10])
    XA = Conv2D(32, (3,3), padding='same', activation='relu')(sum8)

    Y = Conv2DTranspose(filters=3, kernel_size = (9,9), strides = (scale,scale), padding="same",activation=None)(XA)

    X_out = depth_to_space(Y, scale)
    model = Model(inputs=X_in, outputs=X_out)


    model.compile(optimizer=Adam(learning_rate=1e-3),loss=MeanSquaredError(),metrics=[hf.PSNR])

    return model

# %%
from tabnanny import verbose
import tensorflow as tf
from Model import IRMRIS
import pandas as pd
import HelpFunc as hf
import numpy as np
import argparse
import os

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--epoch', type=int, default=100, help='-')
parser.add_argument('--batch_size', type=int, default=128, help='-')

FLAGS, unparsed = parser.parse_known_args()

X_tr = np.load("dataset/data_train.npy")
Y_tr = np.load("dataset/labels_train.npy")

X_val = np.load("dataset/data_validation.npy")
Y_val = np.load("dataset/labels_validation.npy")

X_te = np.load("dataset/data_test.npy")
Y_te = np.load("dataset/labels_test.npy")

model = IRMRIS()

ckpt_path = "checkpoint/model-ckpt"
ckpt_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=ckpt_path,
    save_weights_only=True,
    verbose=1
)

if os.path.exists(f"{ckpt_path}.index"):
    print(f"\n\nLoad Model from \"{ckpt_path}\"")
    model.load_weights(ckpt_path)
else:
    print(f"\n\n\"{ckpt_path}\" DO NOT EXIST")


if os.path.exists("checkpoint/cur_epoch.npy"):
    cur_epoch = np.load("checkpoint/cur_epoch.npy")
else:
    cur_epoch = np.int32(0)
print(f"\n\nCurrent epoch is {cur_epoch}\n")


print("\n\n==================================================",
      " Train ",
      "==================================================\n")

history = model.fit(
    x=X_tr, y=Y_tr,
    batch_size=FLAGS.batch_size,
    epochs=FLAGS.epoch,
    validation_data=(X_val, Y_val),
    callbacks=[ckpt_callback],
    verbose=1
)

print("\n\n==================================================",
      " Evaluate ",
      "==================================================\n")

model.evaluate(X_te, Y_te)

df = pd.DataFrame(history.history)
df = hf.AppendHistory(df)
df.to_csv("history.csv", index=False)

cur_epoch = cur_epoch + FLAGS.epoch
print(f"\nTotal trained epochs is {cur_epoch}\n")

np.save("checkpoint/cur_epoch.npy", cur_epoch)
# Out:
# "checkpoint/model-ckpt" DO NOT EXIST
#
#
# Current epoch is 0
#
#
#
# ==================================================  Train  ==================================================
#
# Epoch 1/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0426 - PSNR: 15.6127
# Epoch 00001: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 5s 7ms/step - loss: 0.0426 - PSNR: 15.6127 - val_loss: 0.0089 - val_PSNR: 20.5063
# Epoch 2/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0065 - PSNR: 21.9627
# Epoch 00002: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0064 - PSNR: 21.9788 - val_loss: 0.0053 - val_PSNR: 22.7692
# Epoch 3/100
# 386/394 [============================>.] - ETA: 0s - loss: 0.0045 - PSNR: 23.4572
# Epoch 00003: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0045 - PSNR: 23.4611 - val_loss: 0.0043 - val_PSNR: 23.7270
# Epoch 4/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0038 - PSNR: 24.2627- ETA: 0s - loss: 0.0039 -
# Epoch 00004: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0038 - PSNR: 24.2627 - val_loss: 0.0037 - val_PSNR: 24.3495
# Epoch 5/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0033 - PSNR: 24.8379
# Epoch 00005: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0033 - PSNR: 24.8435 - val_loss: 0.0033 - val_PSNR: 24.8808
# Epoch 6/100
# 392/394 [============================>.] - ETA: 0s - loss: 0.0029 - PSNR: 25.3497
# Epoch 00006: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0029 - PSNR: 25.3524 - val_loss: 0.0030 - val_PSNR: 25.3197
# Epoch 7/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0026 - PSNR: 25.8272
# Epoch 00007: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0026 - PSNR: 25.8265 - val_loss: 0.0026 - val_PSNR: 25.8272
# Epoch 8/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0023 - PSNR: 26.5045
# Epoch 00008: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0023 - PSNR: 26.5061 - val_loss: 0.0022 - val_PSNR: 26.5324
# Epoch 9/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0020 - PSNR: 26.9862
# Epoch 00009: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0020 - PSNR: 26.9890 - val_loss: 0.0021 - val_PSNR: 26.7259
# Epoch 10/100
# 392/394 [============================>.] - ETA: 0s - loss: 0.0020 - PSNR: 27.0534
# Epoch 00010: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0020 - PSNR: 27.0549 - val_loss: 0.0021 - val_PSNR: 26.8005
# Epoch 11/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.2033
# Epoch 00011: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.2019 - val_loss: 0.0021 - val_PSNR: 26.8456
# Epoch 12/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.2139
# Epoch 00012: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.2044 - val_loss: 0.0024 - val_PSNR: 26.3096
# Epoch 13/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.2349- ETA: 0s - loss: 0.0019 - P
# Epoch 00013: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.2324 - val_loss: 0.0021 - val_PSNR: 26.8811
# Epoch 14/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.2436
# Epoch 00014: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.2414 - val_loss: 0.0021 - val_PSNR: 26.8906
# Epoch 15/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.2101
# Epoch 00015: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.2085 - val_loss: 0.0022 - val_PSNR: 26.5254
# Epoch 16/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.2866
# Epoch 00016: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.2864 - val_loss: 0.0020 - val_PSNR: 26.9099
# Epoch 17/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.2752
# Epoch 00017: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.2753 - val_loss: 0.0020 - val_PSNR: 26.9269
# Epoch 18/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.2896
# Epoch 00018: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.2899 - val_loss: 0.0021 - val_PSNR: 26.7134
# Epoch 19/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.2983
# Epoch 00019: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.2973 - val_loss: 0.0020 - val_PSNR: 26.9423
# Epoch 20/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3035
# Epoch 00020: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.2984 - val_loss: 0.0021 - val_PSNR: 26.8748
# Epoch 21/100
# 386/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3106- ETA: 0s - loss: 0.0019 - PSN
# Epoch 00021: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3128 - val_loss: 0.0020 - val_PSNR: 26.9527
# Epoch 22/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3179
# Epoch 00022: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3201 - val_loss: 0.0020 - val_PSNR: 26.9215
# Epoch 23/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3172
# Epoch 00023: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3061 - val_loss: 0.0021 - val_PSNR: 26.8983
# Epoch 24/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3406
# Epoch 00024: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0019 - PSNR: 27.3410 - val_loss: 0.0020 - val_PSNR: 26.9613
# Epoch 25/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3274
# Epoch 00025: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3275 - val_loss: 0.0020 - val_PSNR: 26.9666
# Epoch 26/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3416
# Epoch 00026: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3414 - val_loss: 0.0020 - val_PSNR: 26.9685
# Epoch 27/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3247
# Epoch 00027: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3260 - val_loss: 0.0020 - val_PSNR: 26.9678
# Epoch 28/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3600
# Epoch 00028: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3575 - val_loss: 0.0021 - val_PSNR: 26.9036
# Epoch 29/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3435
# Epoch 00029: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3390 - val_loss: 0.0020 - val_PSNR: 26.9756
# Epoch 30/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3442
# Epoch 00030: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3429 - val_loss: 0.0020 - val_PSNR: 26.9674
# Epoch 31/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3490
# Epoch 00031: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3483 - val_loss: 0.0020 - val_PSNR: 26.9495
# Epoch 32/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3533
# Epoch 00032: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3551 - val_loss: 0.0020 - val_PSNR: 26.9372
# Epoch 33/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3579
# Epoch 00033: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3552 - val_loss: 0.0020 - val_PSNR: 26.9660
# Epoch 34/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0019 - PSNR: 27.3520
# Epoch 00034: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3520 - val_loss: 0.0020 - val_PSNR: 26.9763
# Epoch 35/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3516
# Epoch 00035: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0019 - PSNR: 27.3545 - val_loss: 0.0020 - val_PSNR: 26.9816
# Epoch 36/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3570
# Epoch 00036: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3569 - val_loss: 0.0020 - val_PSNR: 26.9838
# Epoch 37/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3592
# Epoch 00037: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3587 - val_loss: 0.0020 - val_PSNR: 26.9723
# Epoch 38/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3528
# Epoch 00038: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3575 - val_loss: 0.0020 - val_PSNR: 26.9828
# Epoch 39/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0019 - PSNR: 27.3581
# Epoch 00039: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0019 - PSNR: 27.3593 - val_loss: 0.0020 - val_PSNR: 26.9849
# Epoch 40/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3679
# Epoch 00040: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3700 - val_loss: 0.0020 - val_PSNR: 26.9854
# Epoch 41/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3721
# Epoch 00041: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3705 - val_loss: 0.0020 - val_PSNR: 26.9827
# Epoch 42/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3643
# Epoch 00042: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3611 - val_loss: 0.0020 - val_PSNR: 26.9829
# Epoch 43/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3699
# Epoch 00043: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0019 - PSNR: 27.3647 - val_loss: 0.0020 - val_PSNR: 26.9417
# Epoch 44/100
# 386/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3650
# Epoch 00044: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0019 - PSNR: 27.3634 - val_loss: 0.0020 - val_PSNR: 26.9842
# Epoch 45/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3773
# Epoch 00045: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3764 - val_loss: 0.0020 - val_PSNR: 26.9806
# Epoch 46/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3633- ETA: 0s - loss: 0.00
# Epoch 00046: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3576 - val_loss: 0.0020 - val_PSNR: 26.9839
# Epoch 47/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3698
# Epoch 00047: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3698 - val_loss: 0.0020 - val_PSNR: 26.9844
# Epoch 48/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3620
# Epoch 00048: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3663 - val_loss: 0.0020 - val_PSNR: 26.9911
# Epoch 49/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3660
# Epoch 00049: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3702 - val_loss: 0.0020 - val_PSNR: 26.9344
# Epoch 50/100
# 385/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3716
# Epoch 00050: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3713 - val_loss: 0.0020 - val_PSNR: 26.9894
# Epoch 51/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3690
# Epoch 00051: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3744 - val_loss: 0.0020 - val_PSNR: 26.9869
# Epoch 52/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3720
# Epoch 00052: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3729 - val_loss: 0.0021 - val_PSNR: 26.8714
# Epoch 53/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3619
# Epoch 00053: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3730 - val_loss: 0.0020 - val_PSNR: 26.9852
# Epoch 54/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3789- ETA: 0s - loss: 0.0018 - PSNR: 27.
# Epoch 00054: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3758 - val_loss: 0.0020 - val_PSNR: 26.9891
# Epoch 55/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3706- ETA: 1s - loss: 0.00
# Epoch 00055: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3728 - val_loss: 0.0020 - val_PSNR: 26.9869
# Epoch 56/100
# 385/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3850
# Epoch 00056: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3791 - val_loss: 0.0020 - val_PSNR: 26.9949
# Epoch 57/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3782
# Epoch 00057: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3774 - val_loss: 0.0020 - val_PSNR: 26.9914
# Epoch 58/100
# 386/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3750
# Epoch 00058: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3753 - val_loss: 0.0020 - val_PSNR: 26.9924
# Epoch 59/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3732
# Epoch 00059: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3738 - val_loss: 0.0020 - val_PSNR: 26.9929
# Epoch 60/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3756
# Epoch 00060: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3764 - val_loss: 0.0020 - val_PSNR: 26.9943
# Epoch 61/100
# 385/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3714
# Epoch 00061: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3804 - val_loss: 0.0020 - val_PSNR: 26.9867
# Epoch 62/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3794
# Epoch 00062: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3825 - val_loss: 0.0020 - val_PSNR: 26.9925
# Epoch 63/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3790
# Epoch 00063: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3790 - val_loss: 0.0020 - val_PSNR: 26.9887
# Epoch 64/100
# 385/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3784
# Epoch 00064: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3771 - val_loss: 0.0020 - val_PSNR: 26.9950
# Epoch 65/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3814
# Epoch 00065: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3801 - val_loss: 0.0020 - val_PSNR: 26.9864
# Epoch 66/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3852
# Epoch 00066: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3821 - val_loss: 0.0020 - val_PSNR: 26.9964
# Epoch 67/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3810
# Epoch 00067: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3810 - val_loss: 0.0020 - val_PSNR: 26.9811
# Epoch 68/100
# 385/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3781
# Epoch 00068: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3790 - val_loss: 0.0020 - val_PSNR: 26.9889
# Epoch 69/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3818- ETA: 1s - loss:
# Epoch 00069: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3812 - val_loss: 0.0020 - val_PSNR: 26.9900
# Epoch 70/100
# 385/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3797
# Epoch 00070: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3826 - val_loss: 0.0020 - val_PSNR: 26.9943
# Epoch 71/100
# 392/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3796
# Epoch 00071: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3809 - val_loss: 0.0020 - val_PSNR: 26.9980
# Epoch 72/100
# 386/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3828
# Epoch 00072: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3784 - val_loss: 0.0020 - val_PSNR: 26.9950
# Epoch 73/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3731
# Epoch 00073: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3722 - val_loss: 0.0020 - val_PSNR: 26.9972
# Epoch 74/100
# 392/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3819
# Epoch 00074: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3805 - val_loss: 0.0020 - val_PSNR: 26.9863
# Epoch 75/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3749
# Epoch 00075: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3749 - val_loss: 0.0020 - val_PSNR: 26.9792
# Epoch 76/100
# 385/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3751
# Epoch 00076: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3774 - val_loss: 0.0020 - val_PSNR: 26.9859
# Epoch 77/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3836
# Epoch 00077: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3812 - val_loss: 0.0020 - val_PSNR: 26.9983
# Epoch 78/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3794
# Epoch 00078: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3818 - val_loss: 0.0020 - val_PSNR: 26.9923
# Epoch 79/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3852
# Epoch 00079: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3852 - val_loss: 0.0020 - val_PSNR: 26.9458
# Epoch 80/100
# 387/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3785
# Epoch 00080: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3773 - val_loss: 0.0020 - val_PSNR: 26.9882
# Epoch 81/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3768
# Epoch 00081: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3767 - val_loss: 0.0020 - val_PSNR: 26.9973
# Epoch 82/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3863
# Epoch 00082: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3863 - val_loss: 0.0020 - val_PSNR: 26.9963
# Epoch 83/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3790
# Epoch 00083: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3792 - val_loss: 0.0020 - val_PSNR: 26.9833
# Epoch 84/100
# 392/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3853
# Epoch 00084: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3835 - val_loss: 0.0020 - val_PSNR: 26.9961
# Epoch 85/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3813
# Epoch 00085: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3804 - val_loss: 0.0020 - val_PSNR: 26.9657
# Epoch 86/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3897
# Epoch 00086: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3856 - val_loss: 0.0020 - val_PSNR: 26.9934
# Epoch 87/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3860
# Epoch 00087: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3849 - val_loss: 0.0020 - val_PSNR: 26.9953
# Epoch 88/100
# 391/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3807- ETA: 0s - loss: 0.0018 - PSNR: 27.37
# Epoch 00088: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3816 - val_loss: 0.0020 - val_PSNR: 26.9959
# Epoch 89/100
# 385/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3861
# Epoch 00089: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3825 - val_loss: 0.0020 - val_PSNR: 26.9172
# Epoch 90/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3852- ETA: 0s - loss: 0.0018 - PSN
# Epoch 00090: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3852 - val_loss: 0.0020 - val_PSNR: 26.9989
# Epoch 91/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3837
# Epoch 00091: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 2s 6ms/step - loss: 0.0018 - PSNR: 27.3826 - val_loss: 0.0020 - val_PSNR: 26.9923
# Epoch 92/100
# 393/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3875- E
# Epoch 00092: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3874 - val_loss: 0.0020 - val_PSNR: 26.9384
# Epoch 93/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3866
# Epoch 00093: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3894 - val_loss: 0.0020 - val_PSNR: 26.9905
# Epoch 94/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3786
# Epoch 00094: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3786 - val_loss: 0.0020 - val_PSNR: 26.9318
# Epoch 95/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3834
# Epoch 00095: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3831 - val_loss: 0.0020 - val_PSNR: 26.9992
# Epoch 96/100
# 390/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3857
# Epoch 00096: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3871 - val_loss: 0.0020 - val_PSNR: 26.9975
# Epoch 97/100
# 388/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3850
# Epoch 00097: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3851 - val_loss: 0.0020 - val_PSNR: 26.9960
# Epoch 98/100
# 386/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3902
# Epoch 00098: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 7ms/step - loss: 0.0018 - PSNR: 27.3901 - val_loss: 0.0020 - val_PSNR: 27.0005
# Epoch 99/100
# 389/394 [============================>.] - ETA: 0s - loss: 0.0018 - PSNR: 27.3844
# Epoch 00099: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 6ms/step - loss: 0.0018 - PSNR: 27.3862 - val_loss: 0.0020 - val_PSNR: 26.9948
# Epoch 100/100
# 394/394 [==============================] - ETA: 0s - loss: 0.0018 - PSNR: 27.3839
# Epoch 00100: saving model to checkpoint\model-ckpt
# 394/394 [==============================] - 3s 8ms/step - loss: 0.0018 - PSNR: 27.3839 - val_loss: 0.0020 - val_PSNR: 26.9947
#
#
# ==================================================  Evaluate  ==================================================
#
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0021 - PSNR: 26.9574
#
#
# history file does not exist
#
#
# Total trained epochs is 100
